# %%
from transformers import AutoTokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
# Out:
# ...
# c:\Users\dieyo\AppData\Local\Programs\Python\Python39\lib\site-packages\huggingface_hub\file_download.py:137: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\dieyo\.cache\huggingface\hub. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
# Out:
# {'[PAD]': 0, '[UNK]': 100, '[CLS]': 101, '[SEP]': 102, '[MASK]': 103}

# %%
encoded = tokenizer.encode(input_text)
tokenizer.decode(encoded)
# Out:
# '[CLS] 솨람이 미래다. 열심히 준비하는 [UNK], 문재인입니다! hello, this is olover 쌤입니다! [SEP]'

# %%
input_text = '솨람이 미래다. 열심히 준비하는 댓통령, 문재인입니다! Hello, This is olover 쌤입니다!'
oov_words = []
for word in input_text.split():
    if tokenizer.convert_tokens_to_ids([word]) == [tokenizer.unk_token_id]:
        oov_words.append(word)
print(oov_words)
# Out:
# ['솨람이', '미래다.', '열심히', '준비하는', '댓통령,', '문재인입니다!', 'Hello,', 'This', 'olover', '쌤입니다!']

# %%
tokenizer.decode(tokened)
# Out:
# '[CLS] 사람이 미래다 [SEP] 문재인 [SEP]'

# %%
tokenizer.encode("I'll always falling fallen in love with you")
# Out:
# [101, 1045, 1005, 2222, 2467, 4634, 5357, 1999, 2293, 2007, 2017, 102]

# %%
tokenizer.get_vocab()
# Out:
# {'[unused411]': 416,
#  'chanting': 22417,
#  'bronx': 14487,
#  'bitterness': 22364,
#  'phones': 11640,
#  'buster': 18396,
#  'stronghold': 16995,
#  'clients': 7846,
#  '##thal': 24090,
#  'occult': 27906,
#  'nagasaki': 27107,
#  'gregory': 7296,
#  '##iness': 9961,
#  '##sable': 19150,
#  'deterioration': 26118,
#  'nuclear': 4517,
#  'issn': 23486,
#  'establishment': 5069,
#  'graz': 26918,
#  'stating': 5517,
#  'robe': 11111,
#  'waving': 12015,
#  'sparhawk': 13709,
#  'afb': 16909,
#  'occurrences': 27247,
#  '##ტ': 29989,
#  'cummings': 20750,
#  '##sie': 11741,
#  '##nated': 23854,
#  'enigma': 26757,
#  'administering': 28965,
#  'mare': 11941,
#  'stealing': 11065,
#  'noah': 7240,
#  'cycling': 9670,
#  'mourning': 16236,
#  'fragrance': 24980,
#  'getting': 2893,
#  'violin': 6710,
#  'curly': 17546,
#  '##frame': 15643,
#  'regional': 3164,
#  'exposition': 13080,
#  'tournament': 2977,
#  'finite': 10713,
#  'guillermo': 21070,
#  'unacceptable': 21873,
# ...
